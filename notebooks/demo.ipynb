# %% [markdown]
# # Evidence-Based Research Assistant Agent Demo
# This notebook demonstrates the capstone prototype workflow.

# %%
from pathlib import Path
from src.controller import ResearchAssistantController
controller = ResearchAssistantController(Path('data/sample_docs'))
result = controller.run('Why is retrieval important for a research assistant agent?')
print(result['answer'])
